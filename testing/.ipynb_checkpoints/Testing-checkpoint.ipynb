# %%
import asyncio
from pathlib import Path

import httpx

# %%
# !pip freeze
# Out:
# accelerate==1.10.1
# aiofiles==24.1.0
# aiohappyeyeballs==2.6.1
# aiohttp==3.12.15
# aiosignal==1.4.0
# airportsdata==20250909
# annotated-types==0.7.0
# antlr4-python3-runtime==4.9.3
# anyio==4.9.0
# apify==3.0.5
# apify_client==2.3.0
# apify_shared==2.1.0
# appnope==0.1.4
# argon2-cffi==25.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asttokens==3.0.0
# async-lru==2.0.5
# asyncio==4.0.0
# asyncpg==0.31.0
# attrs==25.3.0
# audioop-lts==0.2.2
# audioread==3.1.0
# babel==2.17.0
# backoff==2.2.1
# bcrypt==4.3.0
# beautifulsoup4==4.13.4
# bidict==0.23.1
# bleach==6.2.0
# blinker==1.9.0
# blobfile==3.1.0
# Brotli==1.1.0
# bs4==0.0.2
# build==1.3.0
# cachetools==5.5.2
# certifi==2025.7.14
# cffi==1.17.1
# chardet==5.2.0
# charset-normalizer==3.4.2
# chromadb==1.0.20
# click==8.2.1
# cloudpickle==3.1.1
# colorama==0.4.6
# coloredlogs==15.0.1
# colorlog==6.9.0
# comm==0.2.3
# contourpy==1.3.3
# crawlee==1.1.1
# cryptography==45.0.6
# cssselect==1.4.0
# cycler==0.12.1
# dataclasses-json==0.6.7
# datasets==4.4.1
# dateparser==1.2.2
# DateTime==5.5
# debugpy==1.8.15
# decorator==5.2.1
# defusedxml==0.7.1
# dill==0.4.0
# diskcache==5.6.3
# distro==1.9.0
# docutils==0.22.2
# durationpy==0.10
# einops==0.8.1
# emoji==2.14.1
# et_xmlfile==2.0.0
# executing==2.2.0
# fastapi==0.116.1
# fastjsonschema==2.21.1
# feedfinder2==0.0.4
# feedparser==6.0.12
# ffmpy==0.6.1
# filelock==3.19.1
# filetype==1.2.0
# Flask==3.1.2
# flatbuffers==25.2.10
# fonttools==4.59.1
# fqdn==1.5.1
# frozenlist==1.7.0
# fsspec==2025.7.0
# genson==1.3.0
# gepa==0.0.22
# google-api-core==2.25.1
# google-api-python-client==2.181.0
# google-auth==2.40.3
# google-auth-httplib2==0.2.0
# google-auth-oauthlib==1.2.2
# googleapis-common-protos==1.70.0
# gradio==5.47.2
# gradio_client==1.13.3
# greenlet==3.2.4
# groovy==0.1.2
# grpcio==1.74.0
# h11==0.16.0
# hf-xet==1.1.8
# hf_transfer==0.1.9
# html5lib==1.1
# httpcore==1.0.9
# httplib2==0.31.0
# httptools==0.6.4
# httpx==0.28.1
# huggingface-hub==0.34.4
# humanfriendly==10.0
# ics==0.7.2
# idna==3.10
# ifaddr==0.2.0
# impit==0.9.3
# importlib_metadata==8.7.0
# importlib_resources==6.5.2
# iniconfig==2.3.0
# interegular==0.3.3
# ipykernel==6.30.0
# ipython==9.4.0
# ipython_pygments_lexers==1.1.1
# ipywidgets==8.1.8
# isoduration==20.11.0
# itsdangerous==2.2.0
# jedi==0.19.2
# jieba3k==0.35.1
# Jinja2==3.1.6
# jiter==0.10.0
# joblib==1.5.1
# json5==0.12.0
# jsonpatch==1.33
# jsonpointer==3.0.0
# jsonschema==4.25.0
# jsonschema-specifications==2025.4.1
# jupyter-events==0.12.0
# jupyter-lsp==2.2.6
# jupyter_client==8.6.3
# jupyter_core==5.8.1
# jupyter_server==2.16.0
# jupyter_server_terminals==0.5.3
# jupyterlab==4.4.5
# jupyterlab_pygments==0.3.0
# jupyterlab_server==2.27.3
# jupyterlab_widgets==3.0.16
# kagglehub==0.3.13
# kiwisolver==1.4.9
# kreuzberg==4.4.1
# kubernetes==33.1.0
# langchain==0.3.27
# langchain-core==0.3.76
# langchain-openai==0.3.33
# langchain-text-splitters==0.3.11
# langdetect==1.0.9
# langgraph==0.6.6
# langgraph-checkpoint==2.1.1
# langgraph-prebuilt==0.6.4
# langgraph-sdk==0.2.4
# langsmith==0.4.21
# lark==1.2.2
# lazy-object-proxy==1.12.0
# lazy_loader==0.4
# librosa==0.11.0
# llvmlite==0.45.1
# lxml==6.0.1
# lxml_html_clean==0.4.3
# markdown-it-py==4.0.0
# markdown2==2.5.4
# MarkupSafe==3.0.2
# marshmallow==3.26.1
# matplotlib==3.10.5
# matplotlib-inline==0.1.7
# mdurl==0.1.2
# mistune==3.1.3
# ml_dtypes==0.5.3
# mmh3==5.2.0
# more-itertools==10.8.0
# mpmath==1.3.0
# msgpack==1.1.2
# multidict==6.6.4
# multiprocess==0.70.18
# mypy_extensions==1.1.0
# nbclient==0.10.2
# nbconvert==7.16.6
# nbformat==5.10.4
# nest-asyncio==1.6.0
# networkx==3.5
# news_articles @ file:///Users/artjomskuzmics/Documents/news_articles/news_articles/backend
# newspaper3k==0.2.8
# nexus-rpc==1.3.0
# nltk==3.9.1
# notebook==7.4.4
# notebook_shim==0.2.4
# numba==0.62.1
# numpy==2.2.6
# oauthlib==3.3.1
# olefile==0.47
# ollama==0.6.0
# omegaconf==2.3.0
# onnx==1.19.0
# onnxruntime==1.22.1
# openai==1.107.1
# opencv-python==4.12.0.88
# openpyxl==3.1.5
# opentelemetry-api==1.36.0
# opentelemetry-exporter-otlp-proto-common==1.36.0
# opentelemetry-exporter-otlp-proto-grpc==1.36.0
# opentelemetry-proto==1.36.0
# opentelemetry-sdk==1.36.0
# opentelemetry-semantic-conventions==0.57b0
# orjson==3.11.3
# ormsgpack==1.10.0
# outlines==0.1.14
# outlines_core==0.1.26
# overrides==7.7.0
# packaging==25.0
# pandas==2.3.1
# pandocfilters==1.5.1
# parso==0.8.4
# pdf2image==1.17.0
# pdfminer.six==20250506
# pexpect==4.9.0
# pi_heif==1.1.0
# pillow==11.3.0
# platformdirs==4.3.8
# playwright==1.56.0
# playwright-stealth==2.0.0
# pluggy==1.6.0
# pooch==1.8.2
# posthog==5.4.0
# prometheus_client==0.22.1
# prompt_toolkit==3.0.51
# propcache==0.3.2
# Protego==0.5.0
# proto-plus==1.26.1
# protobuf==6.32.0
# pscript==0.7.7
# psutil==7.0.0
# psycopg2-binary==2.9.11
# ptyprocess==0.7.0
# pure_eval==0.2.3
# pyaml==25.7.0
# pyarrow==22.0.0
# pyasn1==0.6.1
# pyasn1_modules==0.4.2
# pybase64==1.4.2
# pycountry==24.6.1
# pycparser==2.22
# pycryptodome==3.23.0
# pycryptodomex==3.23.0
# pydantic==2.11.7
# pydantic-settings==2.12.0
# pydantic_core==2.33.2
# pydentic==0.0.1.dev3
# pydub==0.25.1
# pyee==13.0.0
# Pygments==2.19.2
# pyparsing==3.2.3
# pypdf==6.0.0
# pypdfium2==4.30.0
# PyPika==0.48.9
# pyproject_hooks==1.2.0
# pytest==9.0.1
# python-dateutil==2.9.0.post0
# python-docx==1.2.0
# python-dotenv==1.1.1
# python-engineio==4.12.2
# python-iso639==2025.2.18
# python-json-logger==3.3.0
# python-magic==0.4.27
# python-multipart==0.0.20
# python-oxmsg==0.0.2
# python-socketio==5.13.0
# python-stdnum==2.1
# pytz==2025.2
# PyYAML==6.0.2
# pyzmq==27.0.0
# rag_chatbot @ file:///Users/artjomskuzmics/Documents/rag_chatbot/rag-chatbot/rag_chatbot
# RapidFuzz==3.13.0
# readability-lxml==0.8.4.1
# referencing==0.36.2
# regex==2025.7.34
# requests==2.32.4
# requests-file==3.0.1
# requests-oauthlib==2.0.0
# requests-toolbelt==1.0.0
# rfc3339-validator==0.1.4
# rfc3986-validator==0.1.1
# rfc3987-syntax==1.1.0
# rich==14.1.0
# rpds-py==0.26.0
# rsa==4.9.1
# ruff==0.13.2
# safehttpx==0.1.6
# safetensors==0.6.2
# scikit-learn==1.7.1
# scipy==1.16.1
# seaborn==0.13.2
# semantic-version==2.10.0
# Send2Trash==1.8.3
# sentence-transformers==5.1.0
# sentencepiece==0.2.1
# setuptools==80.9.0
# sgmllib3k==1.0.0
# shellingham==1.5.4
# silentcipher @ git+https://github.com/SesameAILabs/silentcipher@d46d7d0893a583d8968ab3a6626e2289faec9152
# simple-websocket==1.1.0
# six==1.17.0
# sniffio==1.3.1
# sounddevice==0.5.0
# soundfile==0.13.1
# soupsieve==2.7
# soxr==1.0.0
# SQLAlchemy==2.0.43
# stack-data==0.6.3
# standard-aifc==3.13.0
# standard-chunk==3.13.0
# standard-sunau==3.13.0
# starlette==0.47.3
# surrealdb==1.0.8
# sympy==1.14.0
# TatSu==5.13.1
# tavily-python==0.7.11
# temporalio==1.23.0
# tenacity==9.1.2
# terminado==0.18.1
# threadpoolctl==3.6.0
# tiktoken==0.11.0
# timm==1.0.19
# tinycss2==1.4.0
# tinysegmenter==0.3
# tldextract==5.3.0
# tokenizers==0.21.4
# tomlkit==0.13.3
# torch==2.8.0
# torchao==0.14.1
# torchdata==0.11.0
# torchtune==0.6.1
# torchvision==0.23.0
# tornado==6.5.1
# tqdm==4.67.1
# traitlets==5.14.3
# transformers==4.55.4
# typer==0.16.1
# types-beautifulsoup4==4.12.0.20250516
# types-html5lib==1.1.11.20251117
# types-protobuf==6.32.1.20251210
# types-python-dateutil==2.9.0.20250708
# types-webencodings==0.5.0.20251108
# typing-inspect==0.9.0
# typing-inspection==0.4.1
# typing_extensions==4.14.1
# tzdata==2025.2
# tzlocal==5.3.1
# unstructured==0.18.14
# unstructured-client==0.42.3
# unstructured-inference==1.0.5
# unstructured.pytesseract==0.3.15
# uri-template==1.3.0
# uritemplate==4.2.0
# urllib3==2.5.0
# uvicorn==0.35.0
# uvloop==0.21.0
# vbuild==0.8.2
# watchfiles==1.1.0
# wcwidth==0.2.13
# webcolors==24.11.1
# webencodings==0.5.1
# websocket-client==1.8.0
# websockets==15.0.1
# Werkzeug==3.1.3
# wheel==0.45.1
# widgetsnbextension==4.0.15
# wrapt==1.17.3
# wsproto==1.2.0
# xlrd==2.0.2
# xxhash==3.5.0
# yarl==1.20.1
# zipp==3.23.0
# zope.interface==8.0
# zstandard==0.24.0

# %%
# Path to meeting notes (project root is backend/..)
NOTES_FILE = Path("__file__").resolve().parent.parent / "testing" / "meeting_notes" / "notes_01.txt"

# %%
async def main():
    notes = NOTES_FILE.read_text().strip()
    url = "http://localhost:8080/process-notes"
    payload = {
        "notes": notes
    }

    print(f"POST {url}")
    print(f"Notes from: {NOTES_FILE}")
    print(f"Notes length: {len(notes)} chars")
    print()

    async with httpx.AsyncClient(timeout=60.0) as client:
        try:
            resp = await client.post(url, json=payload)
        except httpx.ConnectError:
            print("Error: Could not connect to localhost:8000. Is the API server running?")
            print("Start it with: cd backend && uvicorn app.main:app --reload --port 8000")
        except httpx.HTTPStatusError as e:
            print("Error:", e.response.status_code, e.response.text)

        return resp

resp = await main()
# Out:
# POST http://localhost:8080/process-notes
# Notes from: /Users/artjomskuzmics/Documents/Hackathon/meetingminds/testing/meeting_notes/notes_01.txt
# Notes length: 6017 chars

# %%
json.loads(resp.content).keys()
# Out:
# dict_keys(['notes', 'nodes', 'edges'])

# %%
url = "http://localhost:8080/query"

resp = requests.post(
    url, 
    json={"question": "Who is blocked by whom?"}
)

# %%
url = "http://localhost:8080/query"

resp = requests.post(
    url, 
    json={
        "question": "Who is blocked by whom?",
        "surreal_query": "SELECT *, <-blocked_by<-action.* AS blocked_by_actions FROM action;"
    }
)

# %%
for node in json.loads(resp.content)["sub_graph"]:
    for key, value in node.items()
        if not bool(value):
# Out:
# {'blocking_actions': [], 'created_at': '2024-01-15T10:00:00Z', 'description': 'Schedule follow-up meeting', 'id': 'action:1', 'priority': 'high', 'status': 'pending'}

# %%
json.loads(resp.content)
# Out:
# {'question': 'Who is blocked by whom?',
#  'sub_graph': {'action': [{'created_at': '2024-01-15T10:00:00Z',
#     'description': 'Schedule follow-up meeting',
#     'id': 'action:1',
#     'priority': 'high',
#     'status': 'pending'},
#    {'description': 'The action item involves identifying and resolving the coordination failures across teams as highlighted by Helen. This includes addressing duplicate work, untracked vendor spending, and ensuring customer problems are communicated effectively.',
#     'id': 'action:address_coordination_failures',
#     'name': 'Address coordination failures',
#     'type': 'Action'},
#    {'description': 'Rosa Kim is responsible for framing the data findings related to user engagement and churn as a design brief for Daniel Osei. She is expected to complete this by Wednesday, including a full analysis to support design decisions.',
#     'id': 'action:frame_data_findings_as_a_design_brief',
#     'name': 'Frame data findings as a design brief',
#     'type': 'Action'},
#    {'description': "Tom Baxter is responsible for compiling a clear summary of what the Engineering team has built or scoped regarding the notification service. This summary is needed by Clara Whitfield by Thursday to inform decisions about the project's timeline.",
#     'id': 'action:pull_together_a_summary_of_engineering_work',
#     'name': 'Pull together a summary of engineering work',
#     'type': 'Action'},
#    {'description': "Tom Baxter is tasked with compiling a clear summary of what his team has built or scoped regarding the notification service. He needs to deliver this summary by Thursday to inform decisions about the service's timeline.",
#     'id': 'action:pull_together_a_summary_of_the_notification_service',
#     'name': 'Pull together a summary of the notification service',
#     'type': 'Action'},
#    {'description': 'Clara Whitfield will reach out to Sophia Grant to clarify the ownership of the brand guidelines handoff in Marketing. This action is critical to unblock the design work on the notification preferences panel.',
#     'id': 'action:reach_out_to_sophia_grant',
#     'name': 'Reach out to Sophia Grant',
#     'type': 'Action'}],
#   'blocked_by': [{'id': 'blocked_by:0ivdrq2ahpkx0tvqli2c',
#     'in': 'action:reach_out_to_sophia_grant',
#     'out': 'action:frame_data_findings_as_a_design_brief'},
#    {'id': 'blocked_by:59osegewgnjo0w4gh0bv',
#     'in': 'action:pull_together_a_summary_of_the_notification_service',
#     'out': 'action:frame_data_findings_as_a_design_brief'},
#    {'id': 'blocked_by:7gyeoma2z3n4kl3f6otv',
#     'in': 'team:marketing',
#     'out': 'action:reach_out_to_sophia_grant'},
#    {'id': 'blocked_by:8rv7775lm4zqfkwem09l',
#     'in': 'person:daniel_osei',
#     'out': 'action:reach_out_to_sophia_grant'},
#    {'id': 'blocked_by:9ml3vtt0flnojhlnbmxd',
#     'in': 'person:daniel_osei',
#     'out': 'action:reach_out_to_sophia_grant'},
#    {'id': 'blocked_by:baaxrg8877m3rbk9f7k5',
#     'in': 'team:finance_team',
#     'out': 'action:address_coordination_failures'},
#    {'id': 'blocked_by:bfjjatidmjbtwbkh6jre',
#     'in': 'action:reach_out_to_sophia_grant',
#     'out': 'action:pull_together_a_summary_of_the_notification_service'},
#    {'id': 'blocked_by:dydrz98olcwqhynb4mp1',
#     'in': 'action:reach_out_to_sophia_grant',
#     'out': 'action:frame_data_findings_as_a_design_brief'},
#    {'id': 'blocked_by:eoehqfo9kyxkn34ozfng',
#     'in': 'team:engineering',
#     'out': 'action:pull_together_a_summary_of_the_notification_service'},
#    {'id': 'blocked_by:iiyrm7gkbtm0efjoettx',
#     'in': 'team:marketing',
#     'out': 'action:reach_out_to_sophia_grant'},
#    {'id': 'blocked_by:j7i1b4eet8gwoao6a3rx',
#     'in': 'topic:customer_portal_redesign',
#     'out': 'topic:notification_service'},
#    {'id': 'blocked_by:jjuf1pgwmq46b783uti2',
#     'in': 'action:reach_out_to_sophia_grant',
#     'out': 'action:pull_together_a_summary_of_engineering_work'},
#    {'id': 'blocked_by:m68udb6961bi582d1dto',
#     'in': 'team:procurement_team',
#     'out': 'action:address_coordination_failures'},
#    {'id': 'blocked_by:ob7qz0zzkszu44k2a0ol',
#     'in': 'team:marketing',
#     'out': 'action:reach_out_to_sophia_grant'},
#    {'id': 'blocked_by:odtlc5rkn599oftkz2n9',
#     'in': 'team:marketing',
#     'out': 'action:reach_out_to_sophia_grant'},
#    {'id': 'blocked_by:paxv2ri2g42d4c4u44fs',
#     'in': 'team:marketing',
#     'out': 'action:reach_out_to_sophia_grant'},
#    {'id': 'blocked_by:pqthejwmjk9t0g8s2ct2',
#     'in': 'person:daniel_osei',
#     'out': 'action:reach_out_to_sophia_grant'},
#    {'id': 'blocked_by:ty9evb9qqoq5fkzn7hjr',
#     'in': 'topic:customer_portal_redesign',
#     'out': 'topic:notification_service'},
#    {'id': 'blocked_by:vfjagpr9x41wqvir0qiy',
#     'in': 'action:reach_out_to_sophia_grant',
#     'out': 'action:frame_data_findings_as_a_design_brief'},
#    {'id': 'blocked_by:wy3d3lm56y62eggdpr3k',
#     'in': 'team:legal_team',
#     'out': 'action:address_coordination_failures'},
#    {'id': 'blocked_by:zam2384jtdt8ubt0olo0',
#     'in': 'person:daniel_osei',
#     'out': 'action:reach_out_to_sophia_grant'}],
#   'person': [{'email': 'alice@company.com',
#     'id': 'person:alice',
#     'name': 'Alice Johnson',
#     'role': 'Product Manager'},
#    {'description': 'Alicia Torres is the Contracts Manager who attended the Finance & Legal Cross-Functional Sync meeting. Her role likely involves managing contracts and ensuring compliance with legal standards.',
#     'id': 'person:alicia_torres',
#     'name': 'Alicia Torres',
#     'type': 'Person'},
#    {'description': 'Bob was initially blocked by 503 errors in the auth service, which he committed to fixing by Wednesday. He successfully resolved these issues and confirmed that all tests are passing after deployment. His work is crucial for the functionality of the auth service.',
#     'id': 'person:bob',
#     'name': 'Bob',
#     'type': 'Person'},
#    {'description': 'Brett Simmons is the FP&A Lead who presented the Q2 financial model during the Finance & Legal Cross-Functional Sync. He highlighted significant variances in revenue projections and identified issues related to the referral programme.',
#     'id': 'person:brett_simmons',
#     'name': 'Brett Simmons',
#     'type': 'Person'},
#    {'description': 'Carol has made the decision to deprioritize the export feature for the current sprint but later suggested that the team should proceed with it. She plans to write the specification for the feature by Monday, indicating her involvement in its development.',
#     'id': 'person:carol',
#     'name': 'Carol',
#     'type': 'Person'},
#    {'description': 'Clara Whitfield is the Product Manager leading the meeting and overseeing the customer portal redesign initiative. She is focused on ensuring the team has a clear picture of Q2 and is actively addressing blockers, such as the brand guidelines issue raised by Daniel Osei. Clara is responsible for coordinating between teams and ensuring that design and engineering efforts align with the product roadmap.',
#     'id': 'person:clara_whitfield',
#     'name': 'Clara Whitfield',
#     'type': 'Person'},
#    {'description': 'Daniel Osei is the Product Designer working on the customer portal redesign. He has completed wireframes for the dashboard and account settings pages and is currently focused on the notification preferences panel. Daniel raised a blocker regarding the need for updated brand guidelines from Marketing, which is critical for his design work. He is also concerned about ensuring that the UI design aligns with backend capabilities.',
#     'id': 'person:daniel_osei',
#     'name': 'Daniel Osei',
#     'type': 'Person'},
#    {'description': 'David is responsible for upgrading the Kubernetes (K8s) system to version 1.29. He initially committed to completing this by the end of the sprint and later confirmed that the upgrade is complete and running in staging.',
#     'id': 'person:david',
#     'name': 'David',
#     'type': 'Person'},
#    {'description': 'Helen Carter is the Chief Financial Officer (CFO) who has been conducting one-on-one meetings with finance, legal, and procurement teams. She is reporting on significant coordination failures across teams, highlighting issues such as duplicate work and untracked vendor spending. Helen is focused on addressing customer problems and improving financial models that currently have a high level of uncertainty.',
#     'id': 'person:helen_carter',
#     'name': 'Helen Carter',
#     'type': 'Person'},
#    {'description': 'Kwame Asante is the Talent Acquisition lead who reported on the current hiring status during the HR & People Ops Monthly Review. He mentioned that there are nineteen open requisitions and provided details on the interview process for candidates. His insights are crucial for understanding the hiring pace.',
#     'id': 'person:kwame_asante',
#     'name': 'Kwame Asante',
#     'type': 'Person'},
#    {'description': 'Lena Kovacs is the Head of Growth who participated in the meeting. Her role typically involves driving business growth strategies and may intersect with the issues of coordination and customer feedback.',
#     'id': 'person:lena_kovacs',
#     'name': 'Lena Kovacs',
#     'type': 'Person'},
#    {'description': 'Nadia Obi is the Legal Counsel who participated in the Finance & Legal Cross-Functional Sync meeting. Her role involves providing legal guidance and support, particularly in relation to vendor contracts and compliance.',
#     'id': 'person:nadia_obi',
#     'name': 'Nadia Obi',
#     'type': 'Person'},
#    {'description': 'Patricia Downs is the HR Director present in the meeting. She likely plays a role in addressing team dynamics and coordination issues raised by Helen.',
#     'id': 'person:patricia_downs',
#     'name': 'Patricia Downs',
#     'type': 'Person'},
#    {'description': "Priya Nair is an engineer on Tom Baxter's team who is involved in scoping the notification service. She is working alongside another backend engineer to address customer complaints about notification reliability. Priya's input is crucial for aligning the engineering work with the product design.",
#     'id': 'person:priya_nair',
#     'name': 'Priya Nair',
#     'type': 'Person'},
#    {'description': 'Rachel Holm is the Customer Success (CS) Manager who attended the meeting. She is responsible for ensuring customer satisfaction and may be involved in addressing the customer problems mentioned by Helen.',
#     'id': 'person:rachel_holm',
#     'name': 'Rachel Holm',
#     'type': 'Person'},
#    {'description': 'Rosa Kim is the Data Analyst providing insights on user data to inform the redesign of the customer portal. She highlighted significant trends in mobile usage and user engagement, emphasizing the need for a mobile-first approach. Rosa is also analyzing churn signals related to user engagement and onboarding, which are crucial for the redesign strategy.',
#     'id': 'person:rosa_kim',
#     'name': 'Rosa Kim',
#     'type': 'Person'},
#    {'description': 'Simon Kee is the HR Business Partner present in the HR & People Ops Monthly Review. His role typically involves collaborating with business units to align HR strategies with business goals, although specific contributions in this meeting were not highlighted.',
#     'id': 'person:simon_kee',
#     'name': 'Simon Kee',
#     'type': 'Person'},
#    {'description': 'Sophia Grant is mentioned as the owner of the brand guidelines in the Marketing team. Clara Whitfield plans to reach out to her to resolve the blocking issue that Daniel Osei is facing with the notification panel design.',
#     'id': 'person:sophia_grant',
#     'name': 'Sophia Grant',
#     'type': 'Person'},
#    {'description': "Tom Baxter is the Engineering Manager discussing the development of a notification service with his team. He mentioned that two engineers, including Priya Nair, are scoping this service due to customer complaints about in-app notifications. Tom is responsible for ensuring that engineering efforts align with product goals and is tasked with summarizing the team's work on the notification service.",
#     'id': 'person:tom_baxter',
#     'name': 'Tom Baxter',
#     'type': 'Person'},
#    {'description': 'Zara Mitchell is the Learning & Development Manager who attended the HR & People Ops Monthly Review. While her specific contributions were not detailed in the transcript, her role likely involves overseeing training and development initiatives within the organization.',
#     'id': 'person:zara_mitchell',
#     'name': 'Zara Mitchell',
#     'type': 'Person'}]}}

# %%
json.loads(resp.content)["nodes"]
# Out:
# [{'type': 'Person',
#   'name': 'Clara Whitfield',
#   'description': 'Clara Whitfield is the Product Manager leading the meeting. She is focused on ensuring the team has a clear understanding of the Q2 priorities, particularly the customer portal redesign. Clara is actively engaging with team members to address blockers and is committed to reaching out to Sophia Grant for updated brand guidelines. She is also overseeing the integration of data findings into the design process.'},
#  {'type': 'Person',
#   'name': 'Daniel Osei',
#   'description': 'Daniel Osei is the Product Designer responsible for the customer portal redesign. He has completed wireframes for key components and is currently working on the notification preferences panel. Daniel is facing a blocker due to outdated brand guidelines and is seeking assistance to resolve this issue. He emphasizes the importance of aligning design with backend capabilities.'},
#  {'type': 'Person',
#   'name': 'Rosa Kim',
#   'description': 'Rosa Kim is the Data Analyst providing insights on user behavior and data trends related to the customer portal. She highlights the importance of mobile optimization and the need to address onboarding issues to reduce churn. Rosa is tasked with framing data findings into a design brief for the Product Designer, ensuring that the design decisions are data-driven.'},
#  {'type': 'Person',
#   'name': 'Tom Baxter',
#   'description': "Tom Baxter is the Engineering Manager discussing the development of a notification service. He mentions that his team is scoping this service in response to customer feedback. Tom is responsible for coordinating with his engineers and ensuring that their work aligns with the overall product roadmap. He is also tasked with summarizing the team's progress on the notification service."},
#  {'type': 'Person',
#   'name': 'Sophia Grant',
#   'description': 'Sophia Grant is referenced as the owner of the brand guidelines in the Marketing team. Clara Whitfield plans to reach out to her to resolve a blocker affecting the design process for the customer portal.'},
#  {'type': 'Person',
#   'name': 'Priya Nair',
#   'description': "Priya Nair is one of the engineers on Tom Baxter's team, involved in scoping the notification service. She is expected to provide insights on the scope of the project during a call with Tom."},
#  {'type': 'Team',
#   'name': 'Marketing',
#   'description': 'The Marketing team is responsible for maintaining brand guidelines, which are crucial for the design process of the customer portal. Their recent brand refresh has created a dependency for the Product Design team, as updated guidelines are needed to finalize the design.'},
#  {'type': 'Team',
#   'name': 'Engineering',
#   'description': 'The Engineering team, led by Tom Baxter, is working on the notification service and is involved in the backend development for the customer portal redesign. They are coordinating with the Product Design team to ensure that the UI aligns with backend capabilities.'},
#  {'type': 'Topic',
#   'name': 'Customer Portal Redesign',
#   'description': 'The customer portal redesign is the flagship initiative for Q2, focusing on improving user experience based on data insights. The redesign aims to optimize for mobile usage and address onboarding challenges to reduce churn. The project is currently facing a blocker due to outdated brand guidelines.'},
#  {'type': 'Topic',
#   'name': 'Notification Service',
#   'description': 'The notification service is a project being scoped by the Engineering team in response to customer complaints about unreliable in-app notifications. It is on the Q3 roadmap, but there are concerns about potential overlaps with the ongoing work on the customer portal redesign.'},
#  {'type': 'Action',
#   'name': 'Reach out to Sophia Grant for brand guidelines',
#   'description': 'Clara Whitfield will contact Sophia Grant to obtain updated brand guidelines necessary for finalizing the design of the notification preferences panel. This action is critical to resolving the current design blockage.'},
#  {'type': 'Action',
#   'name': 'Pull together a summary of the notification service scope',
#   'description': "Tom Baxter is tasked with compiling a clear summary of what his team has built or scoped regarding the notification service. This summary is needed by Thursday to inform decisions about the project's timeline."},
#  {'type': 'Action',
#   'name': 'Frame data findings as a design brief',
#   'description': 'Rosa Kim is responsible for creating a design brief that incorporates data findings related to user behavior and churn signals. This brief is to be completed by Wednesday and will aid the Product Designer in making informed design decisions.'}]

# %%
json.loads(resp.content)["edges"]
# Out:
# [{'from_id': 'Person:Clara Whitfield',
#   'rel_type': 'assigned_to',
#   'to_id': 'Action:Reach out to Sophia Grant for brand guidelines'},
#  {'from_id': 'Person:Daniel Osei',
#   'rel_type': 'assigned_to',
#   'to_id': 'Action:Pull together a summary of the notification service scope'},
#  {'from_id': 'Person:Rosa Kim',
#   'rel_type': 'assigned_to',
#   'to_id': 'Action:Frame data findings as a design brief'},
#  {'from_id': 'Person:Tom Baxter',
#   'rel_type': 'assigned_to',
#   'to_id': 'Action:Pull together a summary of the notification service scope'},
#  {'from_id': 'Person:Clara Whitfield',
#   'rel_type': 'work_for',
#   'to_id': 'Team:Marketing'},
#  {'from_id': 'Person:Daniel Osei',
#   'rel_type': 'work_for',
#   'to_id': 'Team:Engineering'},
#  {'from_id': 'Person:Rosa Kim',
#   'rel_type': 'work_for',
#   'to_id': 'Team:Marketing'},
#  {'from_id': 'Person:Tom Baxter',
#   'rel_type': 'work_for',
#   'to_id': 'Team:Engineering'},
#  {'from_id': 'Person:Priya Nair',
#   'rel_type': 'work_for',
#   'to_id': 'Team:Engineering'},
#  {'from_id': 'Action:Reach out to Sophia Grant for brand guidelines',
#   'rel_type': 'helps_to_achieve',
#   'to_id': 'Topic:Customer Portal Redesign'},
#  {'from_id': 'Action:Pull together a summary of the notification service scope',
#   'rel_type': 'helps_to_achieve',
#   'to_id': 'Topic:Notification Service'},
#  {'from_id': 'Action:Frame data findings as a design brief',
#   'rel_type': 'helps_to_achieve',
#   'to_id': 'Topic:Customer Portal Redesign'},
#  {'from_id': 'Action:Pull together a summary of the notification service scope',
#   'rel_type': 'blocked_by',
#   'to_id': 'Action:Reach out to Sophia Grant for brand guidelines'},
#  {'from_id': 'Topic:Customer Portal Redesign',
#   'rel_type': 'blocked_by',
#   'to_id': 'Action:Reach out to Sophia Grant for brand guidelines'},
#  {'from_id': 'Topic:Notification Service',
#   'rel_type': 'blocked_by',
#   'to_id': 'Action:Pull together a summary of the notification service scope'},
#  {'from_id': 'Person:Clara Whitfield',
#   'rel_type': 'reports_to',
#   'to_id': 'Person:Tom Baxter'}]

# %%
json.loads(resp.content).keys()

# %%
json.loads(resp.content)["nodes"]
# Out:
# [{'type': 'Person',
#   'name': 'Clara Whitfield',
#   'description': 'Clara Whitfield is the Product Manager leading the meeting. She is focused on ensuring the team has a clear picture of the Q2 roadmap, particularly regarding the customer portal redesign. Clara is actively engaging with team members to address blockers and is committed to reaching out to Sophia Grant in Marketing to resolve the brand guidelines issue. She is also overseeing the integration of data findings into the design process.'},
#  {'type': 'Person',
#   'name': 'Daniel Osei',
#   'description': 'Daniel Osei is the Product Designer responsible for the customer portal redesign. He has completed wireframes for key components and is currently working on the notification preferences panel, which is blocked due to a lack of updated brand guidelines from Marketing. Daniel is also concerned about ensuring the UI design aligns with backend capabilities and is advocating for a mobile-first approach based on user data.'},
#  {'type': 'Person',
#   'name': 'Rosa Kim',
#   'description': 'Rosa Kim is the Data Analyst providing insights on user behavior and data trends related to the customer portal. She highlights the importance of mobile optimization and the need to address onboarding confusion to reduce churn rates. Rosa is tasked with framing data findings into a design brief for Daniel and is expected to include detailed analysis to support design decisions.'},
#  {'type': 'Person',
#   'name': 'Tom Baxter',
#   'description': "Tom Baxter is the Engineering Manager overseeing the engineering team working on the notification service. He reports on the progress of his engineers, including Priya Nair, who are scoping the service in response to customer feedback. Tom is responsible for summarizing the team's work on the notification service and coordinating with Priya to clarify the scope."},
#  {'type': 'Person',
#   'name': 'Priya Nair',
#   'description': "Priya Nair is an engineer on Tom Baxter's team who is involved in scoping the notification service. She is expected to provide insights on the service's architecture and scope during a call with Tom. Her work is critical to ensuring that the engineering efforts align with the product roadmap."},
#  {'type': 'Team',
#   'name': 'Marketing Team',
#   'description': 'The Marketing Team is responsible for maintaining brand guidelines and ensuring that product designs align with the latest branding. They are currently a bottleneck for the design process due to delays in providing updated brand guidelines, which are essential for the completion of the notification preferences panel.'},
#  {'type': 'Team',
#   'name': 'Engineering Team',
#   'description': 'The Engineering Team, led by Tom Baxter, is responsible for developing the notification service and ensuring its functionality aligns with user needs. They are currently scoping the service based on customer feedback and are working on a solution to improve in-app notifications. Their work is interdependent with the design efforts led by Daniel Osei.'},
#  {'type': 'Topic',
#   'name': 'Customer Portal Redesign',
#   'description': 'The Customer Portal Redesign is the flagship initiative for Q2, focusing on improving user experience based on data insights. The redesign aims to optimize the portal for mobile users and address onboarding challenges to reduce churn rates. The project is currently facing challenges related to brand guideline updates and the alignment of design and engineering efforts.'},
#  {'type': 'Topic',
#   'name': 'Notification Service',
#   'description': 'The Notification Service is a project being scoped by the Engineering Team to address customer complaints about unreliable in-app notifications. It is on the Q3 roadmap, but there are concerns about potential overlaps with ongoing work and the need for clear communication between design and engineering to ensure cohesive development.'},
#  {'type': 'Action',
#   'name': 'Clara Whitfield - Reach out to Sophia Grant',
#   'description': 'Clara Whitfield will reach out to Sophia Grant in Marketing to resolve the issue of the updated brand guidelines that are blocking the design of the notification preferences panel. This action is critical to unblocking the design process and ensuring timely progress on the customer portal redesign.'},
#  {'type': 'Action',
#   'name': 'Tom Baxter - Summarize engineering work',
#   'description': 'Tom Baxter is tasked with pulling together a clear summary of what his team has built or scoped regarding the notification service. He is expected to deliver this summary by Thursday to help Clara decide whether to accelerate the notification service into Q2 or pause it until Q3.'},
#  {'type': 'Action',
#   'name': 'Rosa Kim - Frame data findings as design brief',
#   'description': 'Rosa Kim is responsible for framing the data findings related to user behavior and churn signals into a design brief for Daniel Osei. She is expected to complete this by Wednesday and include a detailed analysis to support design decisions.'}]

# %%
json.loads(resp.content)
# Out:
# {'notes': "Meeting 2 — Product Roadmap Review\nDate & Time: Tuesday, February 4, 2026 | 2:00 PM\nAttendees: Clara Whitfield (Product Manager), Daniel Osei (Product Designer), Rosa Kim (Data Analyst), Tom Baxter (Engineering Manager)\nTranscript\n\n\nClara Whitfield: Thanks for joining. I want to make the most of this time — the all-hands is Friday and I need to walk in with a clear picture of Q2. Let's start with the customer portal redesign since that's our flagship initiative for the quarter.\nDaniel Osei: I can give you the full picture. Wireframes for the dashboard and the account settings pages are complete. I actually presented them to the leadership team last week and got broadly positive feedback — the main note was to increase the information density on the dashboard. I'm currently working on the notification preferences panel, which is the most complex part of the redesign because it has a lot of conditional logic depending on user tier.\nClara Whitfield: Great. What's the timeline for finishing the notification panel?\nDaniel Osei: That's where I have a problem. I'm blocked. I need updated brand guidelines from Marketing before I can finalise the colour system across the portal. Right now I'm working with the old palette from 2024, and I know Marketing did a brand refresh in January. If I design the notification panel in the old palette and they hand me new guidelines after, I'll have to redo everything. I've chased them twice last week — sent a Slack and an email — and heard nothing back.\nClara Whitfield: That's frustrating. Do you know who specifically owns the brand guidelines handoff in Marketing?\nDaniel Osei: Sophia Grant's team, I believe. But I'm not sure who the right person is at the working level.\nClara Whitfield: I'll reach out to Sophia directly today. We can't have design blocked on something like that. Rosa, let's talk data. What does usage look like currently and what should it inform about the redesign?\nRosa Kim: A few things worth highlighting. First, mobile — sixty-three percent of portal sessions are mobile, which is up from fifty-one percent a year ago. That's a significant shift and it has to be the primary lens for the redesign. Any interface that isn't optimised for mobile first is going to frustrate the majority of our users. Second, the features with the highest engagement are account management and billing — not the dashboard. Users are coming in to do tasks, not to consume information. That suggests the dashboard-first approach might not be the right hierarchy.\nDaniel Osei: That's really interesting. It might actually justify a rethink of the navigation structure. If users are going straight to account management, maybe that should be the entry point rather than the dashboard.\nClara Whitfield: I agree that's worth exploring. Rosa, is there anything else from the data that should shape our priorities?\nRosa Kim: Yes — churn signals. I've been running a separate analysis on the customer segmentation model and there's a clear pattern: customers who don't engage with the portal in their first thirty days have a significantly higher churn rate at the six-month mark. That points to onboarding being a high-leverage area. If we redesign the portal but the first-time user experience is still confusing, we'll miss the biggest opportunity.\nTom Baxter: That's consistent with what we're hearing from Customer Success. They've had a spike in support tickets about onboarding confusion this week. I was going to raise it separately but it's relevant here.\nClara Whitfield: Tom, before we go further — you mentioned the notification service when we spoke briefly before this meeting. Can you elaborate on what your team is doing?\nTom Baxter: Sure. Two of my engineers — Priya Nair and someone else on the backend team — started scoping a notification service about three weeks ago. It came out of a customer escalation where a large account complained that our in-app notifications were unreliable. They pick ...
#  'nodes': [{'type': 'Person',
#    'name': 'Clara Whitfield',
#    'description': 'Clara Whitfield is the Product Manager leading the meeting. She is focused on ensuring the team has a clear picture of the Q2 roadmap, particularly regarding the customer portal redesign. Clara is actively engaging with team members to address blockers and is committed to reaching out to Sophia Grant in Marketing to resolve the brand guidelines issue. She is also overseeing the integration of data findings into the design process.'},
#   {'type': 'Person',
#    'name': 'Daniel Osei',
#    'description': 'Daniel Osei is the Product Designer responsible for the customer portal redesign. He has completed wireframes for key components and is currently working on the notification preferences panel, which is blocked due to a lack of updated brand guidelines from Marketing. Daniel is also concerned about ensuring the UI design aligns with backend capabilities and is advocating for a mobile-first approach based on user data.'},
#   {'type': 'Person',
#    'name': 'Rosa Kim',
#    'description': 'Rosa Kim is the Data Analyst providing insights on user behavior and data trends related to the customer portal. She highlights the importance of mobile optimization and the need to address onboarding confusion to reduce churn rates. Rosa is tasked with framing data findings into a design brief for Daniel and is expected to include detailed analysis to support design decisions.'},
#   {'type': 'Person',
#    'name': 'Tom Baxter',
#    'description': "Tom Baxter is the Engineering Manager overseeing the engineering team working on the notification service. He reports on the progress of his engineers, including Priya Nair, who are scoping the service in response to customer feedback. Tom is responsible for summarizing the team's work on the notification service and coordinating with Priya to clarify the scope."},
#   {'type': 'Person',
#    'name': 'Priya Nair',
#    'description': "Priya Nair is an engineer on Tom Baxter's team who is involved in scoping the notification service. She is expected to provide insights on the service's architecture and scope during a call with Tom. Her work is critical to ensuring that the engineering efforts align with the product roadmap."},
#   {'type': 'Team',
#    'name': 'Marketing Team',
#    'description': 'The Marketing Team is responsible for maintaining brand guidelines and ensuring that product designs align with the latest branding. They are currently a bottleneck for the design process due to delays in providing updated brand guidelines, which are essential for the completion of the notification preferences panel.'},
#   {'type': 'Team',
#    'name': 'Engineering Team',
#    'description': 'The Engineering Team, led by Tom Baxter, is responsible for developing the notification service and ensuring its functionality aligns with user needs. They are currently scoping the service based on customer feedback and are working on a solution to improve in-app notifications. Their work is interdependent with the design efforts led by Daniel Osei.'},
#   {'type': 'Topic',
#    'name': 'Customer Portal Redesign',
#    'description': 'The Customer Portal Redesign is the flagship initiative for Q2, focusing on improving user experience based on data insights. The redesign aims to optimize the portal for mobile users and address onboarding challenges to reduce churn rates. The project is currently facing challenges related to brand guideline updates and the alignment of design and engineering efforts.'},
#   {'type': 'Topic',
#    'name': 'Notification Service',
#    'description': 'The Notification Service is a project being scoped by the Engineering Team to address customer complaints about unreliable in-app notifications. It is on the Q3 roadmap, but there are concerns about potential overlaps with ongoing work and the need for clear communication between design and engineering to ensure cohesive development.'},
#   {'type': 'Action',
#    'name': 'Clara Whitfield - Reach out to Sophia Grant',
#    'description': 'Clara Whitfield will reach out to Sophia Grant in Marketing to resolve the issue of the updated brand guidelines that are blocking the design of the notification preferences panel. This action is critical to unblocking the design process and ensuring timely progress on the customer portal redesign.'},
#   {'type': 'Action',
#    'name': 'Tom Baxter - Summarize engineering work',
#    'description': 'Tom Baxter is tasked with pulling together a clear summary of what his team has built or scoped regarding the notification service. He is expected to deliver this summary by Thursday to help Clara decide whether to accelerate the notification service into Q2 or pause it until Q3.'},
#   {'type': 'Action',
#    'name': 'Rosa Kim - Frame data findings as design brief',
#    'description': 'Rosa Kim is responsible for framing the data findings related to user behavior and churn signals into a design brief for Daniel Osei. She is expected to complete this by Wednesday and include a detailed analysis to support design decisions.'}],
#  'edges': [{'from_id': 'Person:Clara Whitfield',
#    'rel_type': 'assigned_to',
#    'to_id': 'Action:Clara Whitfield - Reach out to Sophia Grant'},
#   {'from_id': 'Person:Daniel Osei',
#    'rel_type': 'assigned_to',
#    'to_id': 'Action:Rosa Kim - Frame data findings as design brief'},
#   {'from_id': 'Person:Rosa Kim',
#    'rel_type': 'assigned_to',
#    'to_id': 'Action:Rosa Kim - Frame data findings as design brief'},
#   {'from_id': 'Person:Tom Baxter',
#    'rel_type': 'assigned_to',
#    'to_id': 'Action:Tom Baxter - Summarize engineering work'},
#   {'from_id': 'Person:Priya Nair',
#    'rel_type': 'work_for',
#    'to_id': 'Team:Engineering Team'},
#   {'from_id': 'Person:Tom Baxter',
#    'rel_type': 'work_for',
#    'to_id': 'Team:Engineering Team'},
#   {'from_id': 'Person:Clara Whitfield',
#    'rel_type': 'helps_to_achieve',
#    'to_id': 'Topic:Customer Portal Redesign'},
#   {'from_id': 'Action:Clara Whitfield - Reach out to Sophia Grant',
#    'rel_type': 'blocked_by',
#    'to_id': 'Action:Tom Baxter - Summarize engineering work'},
#   {'from_id': 'Action:Tom Baxter - Summarize engineering work',
#    'rel_type': 'helps_to_achieve',
#    'to_id': 'Topic:Notification Service'},
#   {'from_id': 'Action:Rosa Kim - Frame data findings as design brief',
#    'rel_type': 'helps_to_achieve',
#    'to_id': 'Topic:Customer Portal Redesign'},
#   {'from_id': 'Team:Marketing Team',
#    'rel_type': 'blocked_by',
#    'to_id': 'Action:Clara Whitfield - Reach out to Sophia Grant'},
#   {'from_id': 'Team:Engineering Team',
#    'rel_type': 'helps_to_achieve',
#    'to_id': 'Topic:Notification Service'},
#   {'from_id': 'Topic:Customer Portal Redesign',
#    'rel_type': 'helps_to_achieve',
#    'to_id': 'Topic:Notification Service'}]}

# %%
response = {'notes': "Meeting 2 — Product Roadmap Review\nDate & Time: Tuesday, February 4, 2026 | 2:00 PM\nAttendees: Clara Whitfield (Product Manager), Daniel Osei (Product Designer), Rosa Kim (Data Analyst), Tom Baxter (Engineering Manager)\nTranscript\n\n\nClara Whitfield: Thanks for joining. I want to make the most of this time — the all-hands is Friday and I need to walk in with a clear picture of Q2. Let's start with the customer portal redesign since that's our flagship initiative for the quarter.\nDaniel Osei: I can give you the full picture. Wireframes for the dashboard and the account settings pages are complete. I actually presented them to the leadership team last week and got broadly positive feedback — the main note was to increase the information density on the dashboard. I'm currently working on the notification preferences panel, which is the most complex part of the redesign because it has a lot of conditional logic depending on user tier.\nClara Whitfield: Great. What's the timeline for finishing the notification panel?\nDaniel Osei: That's where I have a problem. I'm blocked. I need updated brand guidelines from Marketing before I can finalise the colour system across the portal. Right now I'm working with the old palette from 2024, and I know Marketing did a brand refresh in January. If I design the notification panel in the old palette and they hand me new guidelines after, I'll have to redo everything. I've chased them twice last week — sent a Slack and an email — and heard nothing back.\nClara Whitfield: That's frustrating. Do you know who specifically owns the brand guidelines handoff in Marketing?\nDaniel Osei: Sophia Grant's team, I believe. But I'm not sure who the right person is at the working level.\nClara Whitfield: I'll reach out to Sophia directly today. We can't have design blocked on something like that. Rosa, let's talk data. What does usage look like currently and what should it inform about the redesign?\nRosa Kim: A few things worth highlighting. First, mobile — sixty-three percent of portal sessions are mobile, which is up from fifty-one percent a year ago. That's a significant shift and it has to be the primary lens for the redesign. Any interface that isn't optimised for mobile first is going to frustrate the majority of our users. Second, the features with the highest engagement are account management and billing — not the dashboard. Users are coming in to do tasks, not to consume information. That suggests the dashboard-first approach might not be the right hierarchy.\nDaniel Osei: That's really interesting. It might actually justify a rethink of the navigation structure. If users are going straight to account management, maybe that should be the entry point rather than the dashboard.\nClara Whitfield: I agree that's worth exploring. Rosa, is there anything else from the data that should shape our priorities?\nRosa Kim: Yes — churn signals. I've been running a separate analysis on the customer segmentation model and there's a clear pattern: customers who don't engage with the portal in their first thirty days have a significantly higher churn rate at the six-month mark. That points to onboarding being a high-leverage area. If we redesign the portal but the first-time user experience is still confusing, we'll miss the biggest opportunity.\nTom Baxter: That's consistent with what we're hearing from Customer Success. They've had a spike in support tickets about onboarding confusion this week. I was going to raise it separately but it's relevant here.\nClara Whitfield: Tom, before we go further — you mentioned the notification service when we spoke briefly before this meeting. Can you elaborate on what your team is doing?\nTom Baxter: Sure. Two of my engineers — Priya Nair and someone else on the backend team — started scoping a notification service about three weeks ago. It came out of a customer escalation where a large account complained that our in-app notifications were unreliable. They picked it up proactively rather than waiting for it to be formally scheduled.\nClara Whitfield: The notification service is on our Q3 roadmap. We haven't kicked it off yet precisely because we want to get the portal redesign stable first. Are they building the same thing that's on the roadmap?\nTom Baxter: Honestly, I'm not certain. I haven't fully reviewed their architecture doc. It's possible they're building something narrower — a fix for the existing notification behaviour rather than a full new service. But I can't confirm that without looking at it.\nRosa Kim: That's a real risk. If they build a narrow fix now and we then try to build the full notification service in Q3, we'll have to either integrate with or replace what they built. That could cost more time than just doing it right once.\nDaniel Osei: And from a design standpoint, if Engineering is already building the notification preferences backend, I should be designing the UI in parallel — not as an afterthought once the backend is done. That's how we end up with UIs that don't match what the backend can actually support.\nClara Whitfield: Agreed. Tom, I need you to pull together a clear summary of what your team has built or scoped so far. Can you have that to me by Thursday? I want to decide before Friday's all-hands whether to accelerate the notification service into Q2 or formally pause the grassroots work until Q3.\nTom Baxter: I can do that. I'll also pull Priya into a call tomorrow to get her read on the scope.\nClara Whitfield: Good. On the portal: let's formally adopt a mobile-first approach and Rosa, I'd like you to frame the data findings as a design brief we can share with Daniel. Can you have that by Wednesday?\nRosa Kim: Yes, I'll put it together. Should I include the churn correlation data or keep it high-level?\nClara Whitfield: Include the full analysis. Daniel needs to be able to justify decisions to leadership with data, not just instinct.\nDaniel Osei: That would be really helpful. The more specific the data, the stronger the design rationale.",
 'nodes': [{'type': 'Person',
   'name': 'Clara Whitfield',
   'description': 'Clara Whitfield is the Product Manager leading the meeting. She is focused on ensuring the team has a clear picture of the Q2 roadmap, particularly regarding the customer portal redesign. Clara is actively engaging with team members to address blockers and is committed to reaching out to Sophia Grant in Marketing to resolve the brand guidelines issue. She is also overseeing the integration of data findings into the design process.'},
  {'type': 'Person',
   'name': 'Daniel Osei',
   'description': 'Daniel Osei is the Product Designer responsible for the customer portal redesign. He has completed wireframes for key components and is currently working on the notification preferences panel, which is blocked due to a lack of updated brand guidelines from Marketing. Daniel is also concerned about ensuring the UI design aligns with backend capabilities and is advocating for a mobile-first approach based on user data.'},
  {'type': 'Person',
   'name': 'Rosa Kim',
   'description': 'Rosa Kim is the Data Analyst providing insights on user behavior and data trends related to the customer portal. She highlights the importance of mobile optimization and the need to address onboarding confusion to reduce churn rates. Rosa is tasked with framing data findings into a design brief for Daniel and is expected to include detailed analysis to support design decisions.'},
  {'type': 'Person',
   'name': 'Tom Baxter',
   'description': "Tom Baxter is the Engineering Manager overseeing the engineering team working on the notification service. He reports on the progress of his engineers, including Priya Nair, who are scoping the service in response to customer feedback. Tom is responsible for summarizing the team's work on the notification service and coordinating with Priya to clarify the scope."},
  {'type': 'Person',
   'name': 'Priya Nair',
   'description': "Priya Nair is an engineer on Tom Baxter's team who is involved in scoping the notification service. She is expected to provide insights on the service's architecture and scope during a call with Tom. Her work is critical to ensuring that the engineering efforts align with the product roadmap."},
  {'type': 'Team',
   'name': 'Marketing Team',
   'description': 'The Marketing Team is responsible for maintaining brand guidelines and ensuring that product designs align with the latest branding. They are currently a bottleneck for the design process due to delays in providing updated brand guidelines, which are essential for the completion of the notification preferences panel.'},
  {'type': 'Team',
   'name': 'Engineering Team',
   'description': 'The Engineering Team, led by Tom Baxter, is responsible for developing the notification service and ensuring its functionality aligns with user needs. They are currently scoping the service based on customer feedback and are working on a solution to improve in-app notifications. Their work is interdependent with the design efforts led by Daniel Osei.'},
  {'type': 'Topic',
   'name': 'Customer Portal Redesign',
   'description': 'The Customer Portal Redesign is the flagship initiative for Q2, focusing on improving user experience based on data insights. The redesign aims to optimize the portal for mobile users and address onboarding challenges to reduce churn rates. The project is currently facing challenges related to brand guideline updates and the alignment of design and engineering efforts.'},
  {'type': 'Topic',
   'name': 'Notification Service',
   'description': 'The Notification Service is a project being scoped by the Engineering Team to address customer complaints about unreliable in-app notifications. It is on the Q3 roadmap, but there are concerns about potential overlaps with ongoing work and the need for clear communication between design and engineering to ensure cohesive development.'},
  {'type': 'Action',
   'name': 'Clara Whitfield - Reach out to Sophia Grant',
   'description': 'Clara Whitfield will reach out to Sophia Grant in Marketing to resolve the issue of the updated brand guidelines that are blocking the design of the notification preferences panel. This action is critical to unblocking the design process and ensuring timely progress on the customer portal redesign.'},
  {'type': 'Action',
   'name': 'Tom Baxter - Summarize engineering work',
   'description': 'Tom Baxter is tasked with pulling together a clear summary of what his team has built or scoped regarding the notification service. He is expected to deliver this summary by Thursday to help Clara decide whether to accelerate the notification service into Q2 or pause it until Q3.'},
  {'type': 'Action',
   'name': 'Rosa Kim - Frame data findings as design brief',
   'description': 'Rosa Kim is responsible for framing the data findings related to user behavior and churn signals into a design brief for Daniel Osei. She is expected to complete this by Wednesday and include a detailed analysis to support design decisions.'}],
 'edges': [{'from_id': 'Person:Clara Whitfield',
   'rel_type': 'assigned_to',
   'to_id': 'Action:Clara Whitfield - Reach out to Sophia Grant'},
  {'from_id': 'Person:Daniel Osei',
   'rel_type': 'assigned_to',
   'to_id': 'Action:Rosa Kim - Frame data findings as design brief'},
  {'from_id': 'Person:Rosa Kim',
   'rel_type': 'assigned_to',
   'to_id': 'Action:Rosa Kim - Frame data findings as design brief'},
  {'from_id': 'Person:Tom Baxter',
   'rel_type': 'assigned_to',
   'to_id': 'Action:Tom Baxter - Summarize engineering work'},
  {'from_id': 'Person:Priya Nair',
   'rel_type': 'work_for',
   'to_id': 'Team:Engineering Team'},
  {'from_id': 'Person:Tom Baxter',
   'rel_type': 'work_for',
   'to_id': 'Team:Engineering Team'},
  {'from_id': 'Person:Clara Whitfield',
   'rel_type': 'helps_to_achieve',
   'to_id': 'Topic:Customer Portal Redesign'},
  {'from_id': 'Action:Clara Whitfield - Reach out to Sophia Grant',
   'rel_type': 'blocked_by',
   'to_id': 'Action:Tom Baxter - Summarize engineering work'},
  {'from_id': 'Action:Tom Baxter - Summarize engineering work',
   'rel_type': 'helps_to_achieve',
   'to_id': 'Topic:Notification Service'},
  {'from_id': 'Action:Rosa Kim - Frame data findings as design brief',
   'rel_type': 'helps_to_achieve',
   'to_id': 'Topic:Customer Portal Redesign'},
  {'from_id': 'Team:Marketing Team',
   'rel_type': 'blocked_by',
   'to_id': 'Action:Clara Whitfield - Reach out to Sophia Grant'},
  {'from_id': 'Team:Engineering Team',
   'rel_type': 'helps_to_achieve',
   'to_id': 'Topic:Notification Service'},
  {'from_id': 'Topic:Customer Portal Redesign',
   'rel_type': 'helps_to_achieve',
   'to_id': 'Topic:Notification Service'}]}

# %%
url = "http://localhost:8080/write-graph"

resp = requests.post(
    url, 
    json=response
)

# %%
resp.content
# Out:
# b'{"status":"success"}'

# %%
notes
# Out:
# "Meeting 2 — Product Roadmap Review\nDate & Time: Tuesday, February 4, 2026 | 2:00 PM\nAttendees: Clara Whitfield (Product Manager), Daniel Osei (Product Designer), Rosa Kim (Data Analyst), Tom Baxter (Engineering Manager)\nTranscript\n\n\nClara Whitfield: Thanks for joining. I want to make the most of this time — the all-hands is Friday and I need to walk in with a clear picture of Q2. Let's start with the customer portal redesign since that's our flagship initiative for the quarter.\nDaniel Osei: I can give you the full picture. Wireframes for the dashboard and the account settings pages are complete. I actually presented them to the leadership team last week and got broadly positive feedback — the main note was to increase the information density on the dashboard. I'm currently working on the notification preferences panel, which is the most complex part of the redesign because it has a lot of conditional logic depending on user tier.\nClara Whitfield: Great. What's the timeline for finishing the notification panel?\nDaniel Osei: That's where I have a problem. I'm blocked. I need updated brand guidelines from Marketing before I can finalise the colour system across the portal. Right now I'm working with the old palette from 2024, and I know Marketing did a brand refresh in January. If I design the notification panel in the old palette and they hand me new guidelines after, I'll have to redo everything. I've chased them twice last week — sent a Slack and an email — and heard nothing back.\nClara Whitfield: That's frustrating. Do you know who specifically owns the brand guidelines handoff in Marketing?\nDaniel Osei: Sophia Grant's team, I believe. But I'm not sure who the right person is at the working level.\nClara Whitfield: I'll reach out to Sophia directly today. We can't have design blocked on something like that. Rosa, let's talk data. What does usage look like currently and what should it inform about the redesign?\nRosa Kim: A few things worth highlighting. First, mobile — sixty-three percent of portal sessions are mobile, which is up from fifty-one percent a year ago. That's a significant shift and it has to be the primary lens for the redesign. Any interface that isn't optimised for mobile first is going to frustrate the majority of our users. Second, the features with the highest engagement are account management and billing — not the dashboard. Users are coming in to do tasks, not to consume information. That suggests the dashboard-first approach might not be the right hierarchy.\nDaniel Osei: That's really interesting. It might actually justify a rethink of the navigation structure. If users are going straight to account management, maybe that should be the entry point rather than the dashboard.\nClara Whitfield: I agree that's worth exploring. Rosa, is there anything else from the data that should shape our priorities?\nRosa Kim: Yes — churn signals. I've been running a separate analysis on the customer segmentation model and there's a clear pattern: customers who don't engage with the portal in their first thirty days have a significantly higher churn rate at the six-month mark. That points to onboarding being a high-leverage area. If we redesign the portal but the first-time user experience is still confusing, we'll miss the biggest opportunity.\nTom Baxter: That's consistent with what we're hearing from Customer Success. They've had a spike in support tickets about onboarding confusion this week. I was going to raise it separately but it's relevant here.\nClara Whitfield: Tom, before we go further — you mentioned the notification service when we spoke briefly before this meeting. Can you elaborate on what your team is doing?\nTom Baxter: Sure. Two of my engineers — Priya Nair and someone else on the backend team — started scoping a notification service about three weeks ago. It came out of a customer escalation where a large account complained that our in-app notifications were unreliable. They picked it up p ...

# %%
import requests
NOTES_FILE = Path("__file__").resolve().parent.parent / "testing" / "meeting_notes" / "notes_01.txt"
notes = NOTES_FILE.read_text().strip()
url = "http://localhost:8000/process-notes"
payload = {
    "notes": notes
}

resp = requests.post(url, json=payload)

# %%
resp
# Out:
# <Response [404]>

# %%
resp
# Out:
# <Response [404 Not Found]>
